# %% [markdown]
# Armando Bringas Corpus (A01200230)
# TC4029 Ciencia y analítica de datos (Gpo 10)

# %% [markdown]
# # String Operations

# %% [markdown]
# ## Indexing

# %%
nickname = 'Armi'
nickname
# Out:
# 'Armi'

# %%
# Print first element of the string
print(nickname[0])
# Out:
# A

# %%
# Find the lenght of the string
len(nickname)
# Out:
# 4

# %%
# Print last element of the string
print(nickname[len(nickname) - 1])
# Out:
# i

# %% [markdown]
# ## Negative Indexing

# %%
print(nickname[-1])
# Out:
# i

# %%
# Print first element of the string
# Just complicating things by using negative indexing

print(nickname[-(len(nickname))])
# Out:
# A

# %% [markdown]
# ## Slicing

# %%
nickname[0:3]
# Out:
# 'Arm'

# %% [markdown]
# ## Stride

# %%
# Get every second elements, aka of index 1, 3, 5 and so on...
name = 'Armando Bringas Corpus'
name [::2]
# Out:
# 'AmnoBigsCru'

# %%
# Get every second element in the range from index 0 to index 7
# Kind of fun... mmm, not really!

name[0:8:2]
# Out:
# 'Amno'

# %% [markdown]
# ## Concatenate Strings

# %%
# Concatenate two string
true_statement = name + " wants to find True Love someday. "
true_statement
# Out:
# 'Armando Bringas Corpus wants to find True Love someday. '

# %%
# printing strings multiple times
n_trials = 1800
true_statement * n_trials
# Out:
# 'Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus wants to find True Love someday. Armando Bringas Corpus  ...

# %% [markdown]
# ## Escape Sequences

# %%
# New line

print(" Elvis Presley \n had a great voice.")
# Out:
#  Elvis Presley
#  had a great voice.

# %%
# Tab escape sequence

print(" Elvis Presley \t had a great voice.")
# Out:
#  Elvis Presley 	 had a great voice.

# %%
# Include back slash in string

print(" Elvis Presley \\ had a great voice.")
# Out:
#  Elvis Presley \ had a great voice.

# %%
# To show raw text

# %%
print(r" Elvis Presley \\t\n had a great voice.")
# Out:
#  Elvis Presley \\t\n had a great voice.

# %% [markdown]
# ## String Operations

# %%
# Convert all characters in string to upper case
love_song = "Can't Help Falling in Love"
print("before upper: ", love_song)
print("after upper:", love_song.upper())
# Out:
# before upper:  Can't Help Falling in Love
# after upper: CAN'T HELP FALLING IN LOVE

# %%
# Replacing substrings
not_a_love_song = love_song.replace('Love', 'Hate')
not_a_love_song
# Out:
# "Can't Help Falling in Hate"

# %%
# Find substring
love_song.find('Love')
# Out:
# 22
